# %% [markdown]
# # Simple calculations

# %%
5+5
# Out:
# 10

# %%
10**2
# Out:
# 100

# %%
(5-3) + 7 * 10 / 2
# Out:
# 37.0

# %% [markdown]
# This is my interpretation. The numbers look great!
#
# - here is item1.
# - here is item2.
#     - here is an item below item2.
#
# * list goes on.
#
# 1. the first item in a numbered list.
# 2. the second item in a numbered list.
# 2. the third item in a numbered list.
#
# **Here is a bold text.**
#
# *Here is italic text.*
#
# **Here is a bold text.** <br>
# *Here is italic text.*
#
# <u>Here is underlined text using html.</u>
#
# My dataset has a variable called `eye_color`.
#
# My favorite programming language is python.🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍

# %% [markdown]
# # Let's run some python

# %%
# this is my first line of python code
print('Hello World!') # here is the line
# this is where the line ends.
# Out:
# Hello World!

# %%
# create a variable called 'a', assign 2 to it
a = 2 # a is a variable here!
print(a)
# Out:
# 2

# %%
# works with strings too!
mystring = 'this is my string'
print(mystring)
# Out:
# this is my string

# %%
# create another variable called 'b', assign 3 to it.
b = 3

# multiply a and b?:
a*b
# Out:
# 6

# %%
# Side note: what if you have two things to print?
print(a*b)
print(a*b)
# Out:
# 6
# 6

# %%
# what type of an object is a?
type(a)
# Out:
# int

# %%
# how about 'mystring'?
type(mystring)
# Out:
# str

# %% [markdown]
# # If-else statements

# %%
c = 5

if c > 10:
    print('c is greater than 10!')
else:
    print('c is NOT greater than 10!')
# Out:
# c is NOT greater than 10!

# %% [markdown]
# # For loops

# %%
for i in range(0,10):
    #print(i)
    print('This text needs to be printed 10 times')
# Out:
# This text needs to be printed 10 times
# This text needs to be printed 10 times
# This text needs to be printed 10 times
# This text needs to be printed 10 times
# This text needs to be printed 10 times
# This text needs to be printed 10 times
# This text needs to be printed 10 times
# This text needs to be printed 10 times
# This text needs to be printed 10 times
# This text needs to be printed 10 times

# %%
# what happens if you multiply strings?
star = '*'
print(star*10)
# Out:
# **********

# %%
'mystring'*10
# Out:
# 'mystringmystringmystringmystringmystringmystringmystringmystringmystringmystring'

# %%
for i in range(10): #note that range(10) is equivalent to range(0,10)
    #print(i)
    print('*'*(i+1))
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
# note, you put conditions in for loops:
for i in range(10): #note that range(10) is equivalent to range(0,10)
    #print(i)
    if i == 5: # is i equal to 5?
        break        
    print('*'*(i+1))
# Out:
# *
# **
# ***
# ****
# *****

# %%
c = 10

if c > 10:
    print('c is greater than 10!')
elif c == 10:
    print('c is exactly 10!')
else:
    print('c is less than 10!')
# Out:
# c is exactly 10!

# %%
# how to create your own function?
def myfunc(x): # first define your function, with x being the input
    #print(x**2)
    return x**2

# %%
myfunc(5)
# Out:
# 25

# %%
(myfunc(5))*4 # works!
# Out:
# 100

# %%
myoutput = myfunc(5)
print(myoutput)
# Out:
# 25

# %%
# can you collect information from a user?
name = input('Enter your name: ')
# Out:
# Enter your name:  Eren

# %%
print(name)
# Out:
# Eren

# %%
# Create an input box that receives a number from the user, and that number
# will multiply an object called c

# 'What should we multiply c with?'
# user inputs a number, eg, 5 or 10 or 100 etc.
# and c will be multiplied by that number

# %%
int('50') # int() function takes an input and converts it to integer
# Out:
# 50

# %%
float('20.5') # float() converts strings with decimal numbers to numbers
# Out:
# 20.5

# %%
myoutput = input('What should we multiply c with?')
# Out:
# What should we multiply c with? 5

# %%
type(myoutput)
# Out:
# str

# %%
myoutput = int(myoutput) # be cautious about overwriting in general!

# %%
type(myoutput)
# Out:
# int

# %%
c*myoutput
# Out:
# 50

# %% [markdown]
# # Let's work with numPy!
# Import numpy as follows:

# %%
import numpy as np #np here is an alias/nickname, could have been anything, it saves time typing

# %%
# numpy has a function called random
# if you need to call a function from numpy you can do so as follows:
# optional:
#np.random.seed(42) # freezes the randomizer and makes results reproducable
scores = np.random.normal(75, 10, 1000) # mean=75, sd=10, n=1000
print(scores)
# Out:
# [ 79.96714153  73.61735699  81.47688538  90.23029856  72.65846625
#   72.65863043  90.79212816  82.67434729  70.30525614  80.42560044
#   70.36582307  70.34270246  77.41962272  55.86719755  57.75082167
#   69.37712471  64.8716888   78.14247333  65.91975924  60.87696299
#   89.65648769  72.742237    75.67528205  60.75251814  69.55617275
#   76.1092259   63.49006423  78.75698018  68.9936131   72.0830625
#   68.98293388  93.52278185  74.86502775  64.42289071  83.22544912
#   62.7915635   77.08863595  55.40329876  61.71813951  76.96861236
#   82.3846658   76.71368281  73.84351718  71.98896304  60.2147801
#   67.80155792  70.39361229  85.57122226  78.4361829   57.36959845
#   78.24083969  71.1491772   68.23078     81.11676289  85.30999522
#   84.31280119  66.60782477  71.90787624  78.31263431  84.75545127
#   70.20825762  73.14341023  63.93665026  63.03793376  83.12525822
#   88.56240029  74.27989878  85.03532898  78.61636025  68.54880245
# ...

# %%
type(scores)
# Out:
# numpy.ndarray

# %%
# numpy arrays are similar to lists

# %%
scores*5 # works because scores object is a numpy array
# Out:
# array([399.83570765, 368.08678494, 407.38442691, 451.15149282,
#        363.29233126, 363.29315215, 453.96064078, 413.37173646,
#        351.5262807 , 402.12800218, 351.82911536, 351.71351232,
#        387.09811358, 279.33598777, 288.75410837, 346.88562354,
#        324.35844398, 390.71236663, 329.59879622, 304.38481493,
#        448.28243845, 363.71118498, 378.37641023, 303.76259069,
#        347.78086377, 380.54612949, 317.45032113, 393.78490092,
#        344.9680655 , 360.41531251, 344.91466939, 467.61390923,
#        374.32513876, 322.11445355, 416.12724561, 313.9578175 ,
#        385.44317975, 277.01649381, 308.59069756, 384.84306179,
#        411.923329  , 383.56841406, 369.21758588, 359.94481522,
#        301.07390048, 339.00778958, 351.96806145, 427.85611131,
#        392.18091448, 286.84799223, 391.20419847, 355.74588598,
#        341.15389998, 405.58381444, 426.54997612, 421.56400596,
#        333.03912384, 359.53938121, 391.56317157, 423.77725636,
# ...

# %%
mylist = [1,2,3]

# %%
type(mylist)
# Out:
# list

# %%
mylist*5 # the output here is different than with a numpy array
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# what if you want to round numbers in a numpy array?
np.round(scores,2) # if you want to round to two decimal points
# Out:
# array([ 79.97,  73.62,  81.48,  90.23,  72.66,  72.66,  90.79,  82.67,
#         70.31,  80.43,  70.37,  70.34,  77.42,  55.87,  57.75,  69.38,
#         64.87,  78.14,  65.92,  60.88,  89.66,  72.74,  75.68,  60.75,
#         69.56,  76.11,  63.49,  78.76,  68.99,  72.08,  68.98,  93.52,
#         74.87,  64.42,  83.23,  62.79,  77.09,  55.4 ,  61.72,  76.97,
#         82.38,  76.71,  73.84,  71.99,  60.21,  67.8 ,  70.39,  85.57,
#         78.44,  57.37,  78.24,  71.15,  68.23,  81.12,  85.31,  84.31,
#         66.61,  71.91,  78.31,  84.76,  70.21,  73.14,  63.94,  63.04,
#         83.13,  88.56,  74.28,  85.04,  78.62,  68.55,  78.61,  90.38,
#         74.64,  90.65,  48.8 ,  83.22,  75.87,  72.01,  75.92,  55.12,
#         72.8 ,  78.57,  89.78,  69.82,  66.92,  69.98,  84.15,  78.29,
#         69.7 ,  80.13,  75.97,  84.69,  67.98,  71.72,  71.08,  60.36,
#         77.96,  77.61,  75.05,  72.65,  60.85,  70.79,  71.57,  66.98,
# ...

# %%
# how about choosing elements inside an array?
# how do I select the first item in scores?
scores[0] # returns the first element in scores
# Out:
# np.float64(79.96714153011233)

# %%
scores[1] # returns the second etc.
# Out:
# np.float64(73.61735698828815)

# %%
# what if you want to return scores greater than the mean=75?
scores[scores>75]
# Out:
# array([ 79.96714153,  81.47688538,  90.23029856,  90.79212816,
#         82.67434729,  80.42560044,  77.41962272,  78.14247333,
#         89.65648769,  75.67528205,  76.1092259 ,  78.75698018,
#         93.52278185,  83.22544912,  77.08863595,  76.96861236,
#         82.3846658 ,  76.71368281,  85.57122226,  78.4361829 ,
#         78.24083969,  81.11676289,  85.30999522,  84.31280119,
#         78.31263431,  84.75545127,  83.12525822,  88.56240029,
#         85.03532898,  78.61636025,  78.61395606,  90.38036566,
#         90.64643656,  83.21902504,  75.87047068,  75.91760777,
#         78.57112572,  89.77894045,  84.15402118,  78.2875111 ,
#         80.13267433,  75.97077549,  84.68644991,  77.96120277,
#         77.61055272,  75.05113457,  79.04050857,  93.86185901,
#         76.74577813,  77.57550391,  75.6023021 ,  99.63242112,
#         78.01547342,  86.42822815,  82.51933033,  82.91031947,
#         89.02794311,  80.86857094,  96.90455626,  75.99651365,
# ...

# %%
len(scores[scores>75]) # len() returns the length of an array or list
# Out:
# 510

# %%
# what is the actual mean of scores? In theory it should be 75
np.mean(scores)
# Out:
# np.float64(75.19332055822325)

# %%
# what if you wanted to learn more about a function, eg, np.mean() function?
help(np.mean)
# Out:
# Help on _ArrayFunctionDispatcher in module numpy:
#
# mean(
#     a,
#     axis=None,
#     dtype=None,
#     out=None,
#     keepdims=<no value>,
#     *,
#     where=<no value>
# )
#     Compute the arithmetic mean along the specified axis.
#
#     Returns the average of the array elements.  The average is taken over
#     the flattened array by default, otherwise over the specified axis.
#     `float64` intermediate and return values are used for integer inputs.
#
#     Parameters
#     ----------
#     a : array_like
#         Array containing numbers whose mean is desired. If `a` is not an
#         array, a conversion is attempted.
#     axis : None or int or tuple of ints, optional
#         Axis or axes along which the means are computed. The default is to
#         compute the mean of the flattened array.
#
#         .. versionadded:: 1.7.0
#
#         If this is a tuple of ints, a mean is performed over multiple axes,
# ...

# %% [markdown]
# # Let's now work with Pandas!

# %%
import pandas as pd

# %%
# how do you get data in pandas?
df = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/refs/heads/main/data/2022/2022-01-25/details.csv')

# %%
df
# Out:
#          num      id               primary  \
# 0          0   30549              Pandemic
# 1          1     822           Carcassonne
# 2          2      13                 Catan
# 3          3   68448             7 Wonders
# 4          4   36218              Dominion
# ...      ...     ...                   ...
# 21626  21626  296892          Sacred Rites
# 21627  21627  217378                 BABEL
# 21628  21628   18063              Goldrush
# 21629  21629   10052           Bongo Kongo
# 21630  21630  165946  Green Beret: Vietnam
#
#                                              description  yearpublished  \
# 0      In Pandemic, several virulent diseases have br...           2008
# 1      Carcassonne is a tile-placement game in which ...           2000
# 2      In CATAN (formerly The Settlers of Catan), pla...           1995
# 3      You are the leader of one of the 7 great citie...           2010
# 4      &quot;You are a monarch, like your parents bef...           2008
# ...

# %%
df.shape # returns n and number of cols
# Out:
# (21631, 23)

# %%
df.shape[0] # eg returns n
# Out:
# 21631

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21631 entries, 0 to 21630
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   num                      21631 non-null  int64
#  1   id                       21631 non-null  int64
#  2   primary                  21631 non-null  object
#  3   description              21630 non-null  object
#  4   yearpublished            21631 non-null  int64
#  5   minplayers               21631 non-null  int64
#  6   maxplayers               21631 non-null  int64
#  7   playingtime              21631 non-null  int64
#  8   minplaytime              21631 non-null  int64
#  9   maxplaytime              21631 non-null  int64
#  10  minage                   21631 non-null  int64
#  11  boardgamecategory        21348 non-null  object
#  12  boardgamemechanic        20041 non-null  object
#  13  boardgamefamily          17870 non-null  object
# ...

# %%
df.describe() # gives you summary statistics on all numeric variables in your dataframe
# Out:
#                 num             id  yearpublished    minplayers    maxplayers  \
# count  21631.000000   21631.000000   21631.000000  21631.000000  21631.000000
# mean   10815.000000  118133.093847    1986.094910      2.007027      5.709491
# std     6244.476172  105310.419253     210.042496      0.688957     15.102385
# min        0.000000       1.000000   -3500.000000      0.000000      0.000000
# 25%     5407.500000   12280.500000    2001.000000      2.000000      4.000000
# 50%    10815.000000  105187.000000    2011.000000      2.000000      4.000000
# 75%    16222.500000  207013.000000    2017.000000      2.000000      6.000000
# max    21630.000000  350992.000000    2023.000000     10.000000    999.000000
#
#         playingtime   minplaytime   maxplaytime        minage          owned  \
# count  21631.000000  21631.000000  21631.000000  21631.000000   21631.000000
# mean      90.509177     63.647774     90.509177      9.611391    1487.924553
# ...

# %%
df.yearpublished # return the yearpubished col (lazy way, only works if there is no whitespace in col name)
# Out:
# 0        2008
# 1        2000
# 2        1995
# 3        2010
# 4        2008
#          ...
# 21626    2020
# 21627    2016
# 21628    1970
# 21629    1989
# 21630    2015
# Name: yearpublished, Length: 21631, dtype: int64

# %%
df['yearpublished'] # works even if there is whitespace in the col name
# Out:
# 0        2008
# 1        2000
# 2        1995
# 3        2010
# 4        2008
#          ...
# 21626    2020
# 21627    2016
# 21628    1970
# 21629    1989
# 21630    2015
# Name: yearpublished, Length: 21631, dtype: int64

# %%
df[df['yearpublished'] < 0] # returns all rows that satisft the condition inside df[]
# Out:
#          num     id               primary  \
# 208      208    188                    Go
# 296      296   2397            Backgammon
# 880      880   5432    Chutes and Ladders
# 1029    1029  11901           Tic-Tac-Toe
# 2238    2238   3886     Nine Men's Morris
# 3622    3622   2399                 Senet
# 4088    4088   1602  The Royal Game of Ur
# 4722    4722   5546               Marbles
# 15506  15506  19915    Three Men's Morris
# 16493  16493  21488               Petteia
# 21622  21622  11726          Knucklebones
#
#                                              description  yearpublished  \
# 208    By all appearances, it's just two players taki...          -2200
# 296    Backgammon is a classic abstract strategy game...          -3000
# 880    Traditional game from ancient India was brough...           -200
# 1029   A very old game where each player attempts to ...          -1300
# 2238   Nine Men's Morris is a very old game that has ...          -1400
# ...

# %%
# return games with maxplayers >= 100 (2 mins)
df[df.maxplayers >= 100]
# Out:
#          num      id                                          primary  \
# 130      130  233867                                    Welcome To...
# 191      191  263918                                    Cartographers
# 3341    3341  315767                             Cartographers Heroes
# 4177    4177  147194                                          Linkee!
# 4255    4255  275469                                       Floor Plan
# 4757    4757   32901                                    Prawo Dżungli
# 5382    5382  298586                                          Demeter
# 6491    6491  350736                                          Voyages
# 6893    6893  189890                               Scrimish Card Game
# 8698    8698   24996      Start Player: A Kinda Collectible Card Game
# 9980    9980   60815                     Black Powder: Second Edition
# 10693  10693  319604        Ricochet: A la poursuite du Comte courant
# ...

# %%
df[df.playingtime>10000]
# Out:
#          num      id                                            primary  \
# 2425    2425     254                                    Empires in Arms
# 6417    6417   29285                                          Case Blue
# 9553    9553    4815  The Campaign for North Africa: The Desert War ...
# 10865  10865   46669                         1914: Offensive à outrance
# 13470  13470    6942                                  Drang Nach Osten!
# 13782  13782  158793                    Atlantic Wall: D-Day to Falaise
#
#                                              description  yearpublished  \
# 2425   (from the back of the box - Avalon Hill editio...           1983
# 6417   (from MMP web site:)&#10;&#10;From 1941 throug...           2007
# 9553   This is a wargame like no other.  While the ma...           1979
# 10865  (from GMT website:)&#10;&#10;1914, Offensive &...           2013
# 13470  Introduction:&#10;&#10;Drang Nach Osten! is an...           1973
# ...

# %%
# more mechanics?:
# how do you return the first 10 rows of a df?
df.head(10)
# Out:
#    num      id            primary  \
# 0    0   30549           Pandemic
# 1    1     822        Carcassonne
# 2    2      13              Catan
# 3    3   68448          7 Wonders
# 4    4   36218           Dominion
# 5    5    9209     Ticket to Ride
# 6    6  178900          Codenames
# 7    7  167791  Terraforming Mars
# 8    8  173346     7 Wonders Duel
# 9    9   31260           Agricola
#
#                                          description  yearpublished  \
# 0  In Pandemic, several virulent diseases have br...           2008
# 1  Carcassonne is a tile-placement game in which ...           2000
# 2  In CATAN (formerly The Settlers of Catan), pla...           1995
# 3  You are the leader of one of the 7 great citie...           2010
# 4  &quot;You are a monarch, like your parents bef...           2008
# 5  With elegantly simple gameplay, Ticket to Ride...           2004
# 6  Codenames is an easy party game to solve puzzl...           2015
# ...

# %%
df.iloc[0:10,] # first 10 rows (10th not included, because python never includes second number)
# Out:
#    num      id            primary  \
# 0    0   30549           Pandemic
# 1    1     822        Carcassonne
# 2    2      13              Catan
# 3    3   68448          7 Wonders
# 4    4   36218           Dominion
# 5    5    9209     Ticket to Ride
# 6    6  178900          Codenames
# 7    7  167791  Terraforming Mars
# 8    8  173346     7 Wonders Duel
# 9    9   31260           Agricola
#
#                                          description  yearpublished  \
# 0  In Pandemic, several virulent diseases have br...           2008
# 1  Carcassonne is a tile-placement game in which ...           2000
# 2  In CATAN (formerly The Settlers of Catan), pla...           1995
# 3  You are the leader of one of the 7 great citie...           2010
# 4  &quot;You are a monarch, like your parents bef...           2008
# 5  With elegantly simple gameplay, Ticket to Ride...           2004
# 6  Codenames is an easy party game to solve puzzl...           2015
# ...

# %%
df.iloc[0:10,0:4] # filters to the first 10 rows, and first 4 cols:
# Out:
#    num      id            primary  \
# 0    0   30549           Pandemic
# 1    1     822        Carcassonne
# 2    2      13              Catan
# 3    3   68448          7 Wonders
# 4    4   36218           Dominion
# 5    5    9209     Ticket to Ride
# 6    6  178900          Codenames
# 7    7  167791  Terraforming Mars
# 8    8  173346     7 Wonders Duel
# 9    9   31260           Agricola
#
#                                          description
# 0  In Pandemic, several virulent diseases have br...
# 1  Carcassonne is a tile-placement game in which ...
# 2  In CATAN (formerly The Settlers of Catan), pla...
# 3  You are the leader of one of the 7 great citie...
# 4  &quot;You are a monarch, like your parents bef...
# 5  With elegantly simple gameplay, Ticket to Ride...
# 6  Codenames is an easy party game to solve puzzl...
# 7  In the 2400s, mankind begins to terraform the ...
# 8  In many ways 7 Wonders Duel resembles its pare...
# ...

# %%
# numpy functions, such as mean, median, etc. also work in pandas:
df.playingtime.mean() # returns the mean of playingtime col
# Out:
# np.float64(90.50917664463039)

# %% [markdown]
# # Let's make some viz!

# %%
# We will use matplotlib library:
import matplotlib.pyplot as plt # we only need pyplot sublibrary from matplotlib, give alias 'plt' to it (convention)

# %%
# make a histogram of playingtime:
plt.figure(figsize=(6,3))
plt.hist(df.playingtime, bins=1000, edgecolor='black', color='tomato')
plt.xlim(-10,1000) # this specifies the range of the x axis, -10 gives a slight white space which looks better
plt.xlabel('playing time')
plt.ylabel('# of board games')
plt.savefig('histogramofplayingtime.png',dpi=300, bbox_inches='tight')
plt.show() # gets rid unnecessary text that gets printed

# %%
df.boardgamecategory # this variable potentially has more than 1 category entry, but we need only 1
# Out:
# 0                                              ['Medical']
# 1        ['City Building', 'Medieval', 'Territory Build...
# 2                              ['Economic', 'Negotiation']
# 3        ['Ancient', 'Card Game', 'City Building', 'Civ...
# 4                                ['Card Game', 'Medieval']
#                                ...
# 21626    ['Bluffing', 'Deduction', 'Humor', 'Party Game...
# 21627    ['Action / Dexterity', 'Bluffing', 'Card Game'...
# 21628    ['American West', 'Dice', 'Exploration', 'Figh...
# 21629    ['Action / Dexterity', 'Animals', "Children's ...
# 21630         ['Modern Warfare', 'Vietnam War', 'Wargame']
# Name: boardgamecategory, Length: 21631, dtype: object

# %%
df['category_cleaned'] = df.boardgamecategory.str.split(',').str[0].str.strip("'[] ").str.split(' / ').str[0]
# pick the col, split by comma, pick the first entry, get rid of 4 characters we specified, split again by '/' pick the first entry
df.category_cleaned
# Out:
# 0               Medical
# 1         City Building
# 2              Economic
# 3               Ancient
# 4             Card Game
#               ...
# 21626          Bluffing
# 21627            Action
# 21628     American West
# 21629            Action
# 21630    Modern Warfare
# Name: category_cleaned, Length: 21631, dtype: object

# %%
counts = df.category_cleaned.value_counts()
#df.category_cleaned.value_counts(normalize=True) # presents proportions
counts = counts[counts.values>100] # filters to categories with at least 100 games
counts
# Out:
# category_cleaned
# Card Game             4615
# Abstract Strategy     1545
# Adventure             1144
# Action                1057
# Animals               1049
# Wargame                953
# Bluffing               947
# Economic               896
# Dice                   827
# Ancient                639
# "Children's Game"      587
# Fantasy                583
# Party Game             404
# Deduction              383
# City Building          307
# Aviation               257
# American Civil War     241
# Napoleonic             239
# Medieval               238
# Science Fiction        236
# Fighting               229
# Movies                 229
# Modern Warfare         221
# American West          191
# Exploration            189
# Miniatures             185
# Humor                  172
# Nautical               166
# Age of Reason          162
# Civilization           137
# Racing                 125
# Horror                 123
# Book                   117
# ...

# %%
# bar chart of boardgame categories:
plt.bar(counts.index,counts.values)
plt.xticks(rotation=90)
plt.ylabel('# of boargames')
plt.title('Bar chart showing frequency of categories')
plt.savefig('barchart.png',dpi=300)
plt.show()

# %%
print(counts.index) # prints index (categories)
print(counts.values) # prints the values (counts)
# Out:
# Index(['Card Game', 'Abstract Strategy', 'Adventure', 'Action', 'Animals',
#        'Wargame', 'Bluffing', 'Economic', 'Dice', 'Ancient',
#        '"Children's Game"', 'Fantasy', 'Party Game', 'Deduction',
#        'City Building', 'Aviation', 'American Civil War', 'Napoleonic',
#        'Medieval', 'Science Fiction', 'Fighting', 'Movies', 'Modern Warfare',
#        'American West', 'Exploration', 'Miniatures', 'Humor', 'Nautical',
#        'Age of Reason', 'Civilization', 'Racing', 'Horror', 'Book',
#        'Comic Book', 'Educational', 'Sports', 'Puzzle',
#        'Collectible Components', 'Arabian', 'Civil War', 'Trains', 'Word Game',
#        'Post-Napoleonic', 'Trivia', 'Electronic', 'Real-time', 'Memory',
#        'Political', 'Print & Play', 'Negotiation', 'Territory Building',
#        'Industry', 'Farming', 'Renaissance', 'Transportation', 'Novel-based',
#        'Pirates', 'Environmental', 'Pike and Shot', 'Mythology', 'Prehistoric',
# ...

# %%
counts[counts.index=='Math'] # only 9 math games!
# Out:
# category_cleaned
# Math    9
# Name: count, dtype: int64

# %%
# Scatterplot
# Are games with more minplayers last longer in terms of playingtime?
plt.scatter(df.minplayers,df.playingtime, s=5, alpha=.1)
plt.xlabel('minplayers')
plt.ylabel('playingtime')
plt.show()

# %%
# what is going on around minplayers==2 and playingtime>10000??
df[(df.minplayers==2) & (df.playingtime>10000)]
# Out:
#          num      id                          primary  \
# 2425    2425     254                  Empires in Arms
# 6417    6417   29285                        Case Blue
# 10865  10865   46669       1914: Offensive à outrance
# 13470  13470    6942                Drang Nach Osten!
# 13782  13782  158793  Atlantic Wall: D-Day to Falaise
#
#                                              description  yearpublished  \
# 2425   (from the back of the box - Avalon Hill editio...           1983
# 6417   (from MMP web site:)&#10;&#10;From 1941 throug...           2007
# 10865  (from GMT website:)&#10;&#10;1914, Offensive &...           2013
# 13470  Introduction:&#10;&#10;Drang Nach Osten! is an...           1973
# 13782  (from Decision Games' website)&#10;&#10;ON 6 J...           2014
#
#        minplayers  maxplayers  playingtime  minplaytime  maxplaytime  ...  \
# 2425            2           7        12000          120        12000  ...
# ...

# %%
# Let's look at games with playingtime<180?
filtered_data = df[df.playingtime<180]
# after fitering is done, you can plot:
plt.scatter(filtered_data.minplayers,filtered_data.playingtime, s=5, alpha=.1)
plt.xlabel('minplayers')
plt.ylabel('playingtime')
plt.show()

# %% [markdown]
# There actually appears a negative association between minplayers and playingtime.

# %%
# How about hexagon plot?
plt.hexbin(filtered_data.minplayers,filtered_data.playingtime, gridsize=10, mincnt=0,cmap='Purples')
plt.colorbar()
plt.xlabel('minplayers')
plt.ylabel('playingtime')
plt.show()

# %%
to_plot.sort_values()
# Out:
# yearpublished
# 1897       1
# 1876       1
# 1755       1
# 1819       1
# 1775       1
#         ...
# 2015    1147
# 2019    1258
# 2016    1291
# 2018    1321
# 2017    1325
# Name: count, Length: 190, dtype: int64

# %%
to_plot = df.yearpublished.value_counts()
to_plot
# Out:
# yearpublished
# 2017    1325
# 2018    1321
# 2016    1291
# 2019    1258
# 2015    1147
#         ...
# 1687       1
# 1150       1
# 1630       1
# 1861       1
# 1897       1
# Name: count, Length: 190, dtype: int64

# %%
# convert to_plot object to a DataFrame:
to_plot = df.yearpublished.value_counts()
to_plot = pd.DataFrame(to_plot).reset_index() # reset_index sets all columns to be similarly defined
to_plot = to_plot.sort_values('yearpublished').reset_index(drop=True)
to_plot = to_plot[to_plot.yearpublished>1900]
to_plot
# Out:
#      yearpublished  count
# 81            1903      2
# 82            1904      1
# 83            1906      2
# 84            1908      1
# 85            1909      2
# ..             ...    ...
# 185           2019   1258
# 186           2020    897
# 187           2021    678
# 188           2022    113
# 189           2023      2
#
# [109 rows x 2 columns]

# %%
# connect the dots: line chart
plt.plot(to_plot.yearpublished,to_plot['count'])
plt.xlabel('year')
plt.ylabel('# of boargames')
plt.show()
